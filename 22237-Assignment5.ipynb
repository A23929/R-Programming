# %% [markdown]
# ## Name: Aniruddha
#
# ## Regd No: 22237
#
# ## Date: 8/03/2023
#
# ## R-Lab: ggplot2
#
# ## Assignment 5

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.0     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.1     ✔ tibble    3.2.0
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
mpg
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# ...

# %% [markdown]
# ## Scatter plots

# %%
ggplot(data=mpg)+geom_point(mapping = aes(x = displ, y = cty),size=5)
# Out:
# plot without title

# %% [markdown]
# ## Color of scatter points

# %%
ggplot(data=mpg)+geom_point(mapping = aes(x = displ, y = cty, color = trans),size=5)
# Out:
# plot without title

# %%
ggplot(data=mpg)+geom_point(mapping = aes(x = displ, y = cty, size = year),size=5)
# Out:
# plot without title

# %% [markdown]
# ## Shades of color of scater points

# %%
ggplot(data = mpg) +
 geom_point(mapping = aes(x = displ, y = hwy, alpha = year),size=5)
# Out:
# plot without title

# %% [markdown]
# ## Shapes of scatter points

# %%
ggplot(data = mpg) +
 geom_point(mapping = aes(x = displ, y = hwy, shape = drv),size=5)
# Out:
# plot without title

# %% [markdown]
# ## Marginal Plots

# %%
ggplot(data=mpg,aes(x = displ, y = cty))+geom_count()+geom_smooth(method='lm',se=F)
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# ## Bar plot

# %%
p <- ggplot(mpg,aes(x = factor(class))) + geom_bar(stat = "count")
p
# Out:
# plot without title

# %% [markdown]
# ## Histogram

# %%
ggplot(data=mpg, aes(x=hwy)) + geom_histogram(col='red',fill='green',alpha=.5,binwidth = 5)
# Out:
# plot without title

# %%
library(ggplot2)
data(iris)


IrisPlot <- ggplot(iris, aes(Sepal.Length, Petal.Length, colour=Species)) + geom_point(size=2.56)

# %%
head(iris)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
print(IrisPlot + labs(y="Petal length (cm)", x = "Sepal length (cm)") 
   + ggtitle("Petal and sepal length of iris"))
# Out:
# plot without title

# %% [markdown]
# ## Highlight

# %%
IrisPlot + annotate("rect", xmin = 5, xmax = 7,ymin = 4, ymax = 6, alpha = 0.5)
# Out:
# plot without title

# %% [markdown]
# ## Segment

# %%
IrisPlot + annotate("segment",x=5, xend = 7, y = 4, yend = 5, colour = "black")
# Out:
# plot without title

# %% [markdown]
# ## Overlapping and creating the pattern of required variables

# %%
ggplot(iris, aes(Sepal.Length, Petal.Length, colour=Species)) +
geom_point(shape=1,size=3) +
 geom_smooth(method=lm)
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
df <- as.data.frame(table(iris$Species))
df
# Out:
#   Var1       Freq
# 1 setosa     50
# 2 versicolor 50
# 3 virginica  50

# %%
pie <- ggplot(df, aes(x="",y =Freq, fill = factor(Var1))) + geom_bar(width = 1, stat = "identity") + theme(axis.line = element_blank(),
plot.title = element_text(hjust=0.5)) +
    labs(fill="Freq",
       x=NULL,
       y=NULL, 
       title="Pie Chart of Variety of iris Species",
       caption="Source: iris")

# %% [markdown]
# ## Pie Chart

# %%
pie + coord_polar(theta = "y", start=1)
# Out:
# plot without title
